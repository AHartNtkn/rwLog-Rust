# %% [markdown]
# # rwlog addition demo
#
# This notebook loads the Peano addition relation and runs forward/backward queries.
# If loading fails, adjust the path to match your working directory.

# %%
load addition.txt
# Out:
# Loaded 1 relation(s) from 'addition.txt'

# %%
# 0 + 1 = 1
@(cons z (s z)) ; add
# Out:
# 1. NF { match_pats: [TermId(2)], wire: Wire { in_arity: 0, out_arity: 0, map: [], constraint: () }, build_pats: [TermId(1)] }
# Type 'next' for more answers.

# %%
# 3 + 2 = 5
@(cons (s (s (s z))) (s (s z))) ; add
# Out:
# 1. NF { match_pats: [TermId(5)], wire: Wire { in_arity: 0, out_arity: 0, map: [], constraint: () }, build_pats: [TermId(20)] }
# Type 'next' for more answers.

# %%
# Backwards: all pairs that sum to 5
add ; @(s (s (s (s (s z)))))
# Out:
# 1. NF { match_pats: [TermId(21)], wire: Wire { in_arity: 0, out_arity: 0, map: [], constraint: () }, build_pats: [TermId(20)] }
# Type 'next' for more answers.

# %%
# Next answer
next
# Out:
# No more answers.
