# %%
[$x -> $y] ; [[a -> z] & [b -> z]]
next
# Out:
# No more answers.
# No active query. Run a query first.

# %%
[[z -> a] & [z -> b]] ; [$x -> $y]
next
# Out:
# No more answers.
# No active query. Run a query first.
