# %%
load treecalc.txt
# Out:
# Loaded 1 theory block(s), Loaded 1 relation(s) from 'treecalc.txt'

# %%
[[$x { (no_c $x) } -> (f $x (c z))] ; app ; @(c z)]
next
# Out:
# 1. (f (b (b l)) (f l $0)) { (no_c $0) } -> (c z)
# Type 'next' for more answers.
#
# 2. (f (b (b l)) l) -> (c z)
# Type 'next' for more answers.
