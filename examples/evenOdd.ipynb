# %%
rel even {
    z -> true
  | (s $n) -> $n ; odd
}

rel odd {
    z -> false
  | (s $n) -> $n ; even
}
# Out:
# Defined relation 'even'
# Defined relation 'odd'

# %%
odd ; @true
# Out:
# 1. (s z) -> true
# Type 'next' for more answers.

# %%
next
# Out:
# 3. (s (s (s (s (s z))))) -> true
# Type 'next' for more answers.
